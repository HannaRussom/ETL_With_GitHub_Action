# %%
from get_data import get_article_data

df = get_article_data()
df
# Out:
# https://dev.to/latest
# https://dev.to/javascriptwizzard/why-web-components-are-the-future-of-ui-component-libraries-4je1
# https://dev.to/cjpoulsen/call-for-contributors-3f7e
# https://dev.to/apipie-ai/top-5-ai-coding-models-of-march-2025-5f04
# https://dev.to/luserv/conexion-a-github-usando-ssh-3plm
# https://dev.to/jhonifaber/domain-driven-designddd-understanding-main-concepts-11p3
# https://dev.to/dotmavriq/news-on-fedora-linux-42-beta-5acp
# https://dev.to/mnishiguchi/boost-your-terminal-navigation-with-the-y-z-workflow-291c
# https://dev.to/raju_dandigam/docker-powered-angular-streamlining-deployment-with-nginx-31cm
# https://dev.to/lordneo/csrf-explained-like-youre-five-but-smarter-3mke
# https://dev.to/bogdannovotarskij/profiessionalnaia-riealizatsiia-avtorizatsii-v-vieb-prilozhienii-s-pomoshchiu-supabase-ot-boghdana-novotarskogho-20k6
# https://dev.to/lordneo/cors-explained-like-youre-five-but-smarter-1hon
# https://dev.to/edwinepr/how-to-install-postman-on-fedora-41-standalone-version-32fh
# https://dev.to/quadraticai/quadratic-the-ai-powered-spreadsheet-for-modern-teams-gh2
# https://dev.to/atoms19/algorithms-1-intro-to-sorting-algorithms-i9p
# https://dev.to/yasminbashirova/from-employee-to-entrepreneur-the-identity-shift-no-one-talks-about-by-successful-entrepreneurs-1p5l
# https://dev.to/atoms19/algorithms-intro-to-sorting-algorithms-insertion-sort-and-selection-sort--1105
# https://dev.to/maddiepst/correct-the-mistakes-of-the-character-recognition-software-33gh
# https://dev.to/lmlonghuynh/mastering-api-design-the-power-of-namespaces-and-contracts-3cie
# https://dev.to/lmlonghuynh/mastering-api-design-the-power-of-namespaces-and-contracts-14a7
# https://dev.to/terrateam-io/7-best-terraform-cloud-alternatives-for-2025-58on
# https://dev.to/mshertzberg/ive-written-a-lot-of-tech-specs-now-i-have-this-new-interview-fear-looking-ai-made-i-try-not-35i0
# https://dev.to/aniruddhaadak/a-personal-finance-dashboard-with-kendoreact-eka
# https://dev.to/yumejistudio/calling-developers-designers-creators-and-everyone-lets-build-something-big-together-43oj
# https://dev.to/msnmongare/building-a-todo-list-app-with-elixir-and-phoenix-liveview-3lfn
# https://dev.to/oigorrudel/dica-java-evite-trafegar-objetos-de-dtos-002-265a
# [nltk_data] Downloading package stopwords to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /home/gitpod/nltk_data...
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/gitpod/nltk_data...
# [nltk_data] Downloading package punkt_tab to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 20  I've written a lot of tech specs & now I have ...  2025-03-18T22:26:39Z
# 21       A Personal Finance Dashboard with KendoReact  2025-03-18T22:18:00Z
# 22  🚀 Calling Developers, Designers, Creators and ...  2025-03-18T22:16:30Z
# 23  Building a Todo List App with Elixir and Phoen...  2025-03-18T22:06:53Z
# 24    Dica Java: Evite trafegar objetos de DTO's #002  2025-03-18T22:04:39Z
#
#                      Author                                            Tags  \
# 0                   Pradeep       #webdev#webcomponents#javascript#frontend
# 1       Christopher Poulsen                #kotlin#blockchain#opensource#go
# 2                    Toocky                      #development#coding#llm#ai
# 3                      User                   #ssh#linux#github#programming
# 4                  Jonathan                #architecture#java#design#domain
# 5           Jonatan Jansson                        #fedora#linux#opensource
# 6      Masatoshi Nishiguchi                               #cli#tui#fzf#yazi
# 7             Raju Dandigam                   #webdev#angular#docker#devops
# 8        Someshwar Tripathi
# 9        Богдан Новотарский
# 10       Someshwar Tripathi
# 11            Edwin Enrique        #programming#learning#postman#standalone
# 12                Quadratic                   #showdev#ai#python#javascript
# 13                    atoms
# 14         Yasmin Bashirova
# 15                    atoms                             #sorting#algorithms
# 16          Madalina Pastiu             #challenge#javascript#codewars#8kyu
# 17               Long Huynh       #javascript#typescript#designpatterns#api
# 18               Long Huynh       #javascript#typescript#designpatterns#api
# 19                Terrateam          #terraform#devops#infrastructureascode
# 20  Michael Scott Hertzberg                              #discuss#ai#career
# 21          ANIRUDDHA  ADAK  #devchallenge#kendoreactchallenge#react#webdev
# 22            Angel Ramirez              #webdev#programming#startup#career
# 23        Sospeter Mong'are            #webdev#programming#elixir#beginners
# 24               Igor Rudel                #java#webdev#programming#backend
#
#    Reading Time                                    Article Content  \
# 0    2 min read  What are they?\nWeb Components are a set of na...
# 1    1 min read  Hey everyone! I’m looking for more contributor...
# 2    6 min read   The past year has brought a new generation of...
# 3    2 min read  Usualmente cuando hacemos un git push origin m...
# 4    3 min read  Domain Driven Design(DDD) is a form of softwar...
# 5    1 min read  Fedora Linux 42 Beta just dropped, and I'm hon...
# 6    2 min read  Navigating directories efficiently in the term...
# 7    3 min read  Introduction Deploying an Angular web applicat...
# 8    2 min read  Imagine you’re at a restaurant. You order a pi...
# 9    4 min read  За годы своей практики я понял одну важную вещ...
# 10   2 min read  If you've ever built a web app that fetches da...
# 11   3 min read  Postman is a platform designed for building an...
# 12   2 min read  Spreadsheets have been around for decades, but...
# 13   1 min read  Hey reader , back again ? so lets brush up wha...
# 14   4 min read  Transitioning from an employee to an entrepren...
# 15   6 min read  Hey reader , you have stumbled across a series...
# 16   1 min read  Instructions:\nCharacter recognition software ...
# 17   2 min read  In modern software development, maintaining cl...
# 18   2 min read  In modern software development, maintaining cl...
# 19   3 min read  HashiCorp's pricing model change has prompted ...
# 20   1 min read
# 21   7 min read  This is a submission for the . The app feature...
# 22   2 min read  Hey everyone,\nI’m working on something that I...
# 23   5 min read  This example will walk you through creating a ...
# 24   2 min read  Uma das práticas que venho adotando (ás vezes ...
#
#     Word Count Sentiment  Compound Score
# 0          307  Positive          0.9845
# 1           30  Positive          0.8118
# 2          243  Positive          0.8151
# 3          194  Negative         -0.0516
# 4          441  Positive          0.9676
# 5          179  Positive          0.9881
# 6          193  Positive          0.9777
# 7          296  Positive          0.9902
# 8          169  Negative         -0.8392
# 9          630   Neutral          0.0000
# 10         243  Positive          0.6928
# 11         233  Positive          0.9569
# 12         318  Positive          0.9942
# 13         133  Positive          0.8934
# 14         687  Positive          0.9996
# 15         680  Positive          0.5191
# 16          88  Negative         -0.8360
# 17         240  Positive          0.9900
# 18         240  Positive          0.9900
# 19         500  Positive          0.9986
# 20           0   Neutral          0.0000
# 21         257  Positive          0.9736
# 22         325  Positive          0.9971
# 23          74  Positive          0.4753
# 24         391  Positive          0.3453

# %%
import pandas as pd

df.columns = [x.lower() for x in df.columns]
df.columns = [x.replace(' ','_') for x in df.columns]
df['reading_time'] = df['reading_time'].str.replace(' min read','')
df['article_content'] = df['article_content'].str.replace('\n','')


df = df.astype({
    'link': 'string',
    'title': 'string',
    'time_uploaded': 'string',  # Can be converted to datetime later
    'author': 'string',
    'tags': 'string',
    'reading_time': 'int64',
    'article_content': 'string',
    'word_count': 'int64',
    'sentiment': 'string',
    'compound_score': 'float64'
})


df['time_uploaded'] = pd.to_datetime(df['time_uploaded'])

# %%
import psycopg2
import pandas as pd

# Database connection parameters
db_params = {
    "dbname": "postgres",
    "user": "testtech",
    "password": "Your_password",
    "host": "testtech.postgres.database.azure.com",
    "port": "5432"
}


try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_params)
    cursor = conn.cursor()
    
    # SQL Insert Query
    insert_query = """
    INSERT INTO michael (link, title, time_uploaded, author, tags, reading_time, article_content, word_count, sentiment, compound_score)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (link) DO NOTHING;  -- Avoids duplicate primary key errors
    """
    
    # Insert DataFrame records one by one
    for _, row in df.iterrows():
        cursor.execute(insert_query, (
            row['link'], row['title'], row['time_uploaded'], row['author'], row['tags'],
            row['reading_time'], row['article_content'], row['word_count'], row['sentiment'], row['compound_score']
        ))

    # Commit and close
    conn.commit()
    print("Data inserted successfully!")

except Exception as e:
    print("Error:", e)

finally:
    if conn:
        cursor.close()
        conn.close()




#"password": os.getenv("DB_PASSWORD")
# Out:
# Data inserted successfully!

# %%
pip install psycopg2
# Out:
# Collecting psycopg2
#   Using cached psycopg2-2.9.10-cp312-cp312-linux_x86_64.whl
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10
# Note: you may need to restart the kernel to use updated packages.
