# %%
from get_data import get_article_data

df = get_article_data()
df
# Out:
# https://dev.to/latest
# https://dev.to/this-is-angular/ng-news-2512-nx-angular-week-deprecation-pr-ngifforswitch-9ip
# https://dev.to/vikingcms/full-stack-dev-needed-5h4
# https://dev.to/dimitrije_gujanicic_d0b7b/how-to-automate-outbound-voice-calls-with-ai-using-webrtc-or-twilio-24j2
# https://dev.to/suryanag0999/how-to-deploy-a-vite-react-app-to-github-pages-189i
# https://dev.to/apexgov/compatibilidad-entre-apex-y-base-de-datos-oracle-2l06
# https://dev.to/arekrgw/nextjs-shallow-search-params-routing-3dl6
# https://dev.to/angelamchoi/what-hogwarts-can-teach-us-about-security-5bme
# https://dev.to/francescobianco/convcommit-the-tool-that-makes-conventional-commits-a-habit-2n0n
# https://dev.to/bhabani_sankar/bootstrap-a-complete-guide-3oll
# https://dev.to/lau_blog/the-logic-of-value-4mbb
# https://dev.to/dantesbytes/comprehensive-rust-programming-course-5c6d
# https://dev.to/rijultp/how-to-build-habit-forming-products-using-nir-eyals-hook-model-4mm5
# https://dev.to/samvanhoutte/processing-time-series-data-in-azure-the-options-hhg
# https://dev.to/hijazi313/nextjs-15-scroll-behavior-a-comprehensive-guide-387j
# https://dev.to/leapcell/rust-concurrency-a-beginners-exploration-4om4
# https://dev.to/proga100/slash-your-wordpress-setup-time-to-seconds-with-python-automation-38od
# https://dev.to/michaellarocca/mastering-excel-vlookup-and-custom-vba-functions-for-key-value-data-retrieval-8fc
# https://dev.to/omriluz1/promise-combinators-race-allsettled-any-5d0k
# https://dev.to/bansikah/aws-config-automate-your-cloud-compliance-and-security-2n23
# https://dev.to/proga100/automating-wordpress-site-creation-in-laravel-herd-environments-16l1
# https://dev.to/l_walid/concurrency-gotchas-in-go-25lc
# https://dev.to/yarynakobryn/vistra-review-aa8
# https://dev.to/anacvera/login-seguro-com-robot-framework-protegendo-credenciais-e-reutilizando-codigo-2d6i
# https://dev.to/adityav369/an-overview-of-rules-based-ingestion-in-databridge-nm6
# https://dev.to/kampa/introducing-kampaio-local-dev-environments-without-the-headaches-4m33
# [nltk_data] Downloading package stopwords to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /home/gitpod/nltk_data...
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/gitpod/nltk_data...
# [nltk_data] Downloading package punkt_tab to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                                  Link  \
# 0   https://dev.to/this-is-angular/ng-news-2512-nx...
# 1   https://dev.to/vikingcms/full-stack-dev-needed...
# 2   https://dev.to/dimitrije_gujanicic_d0b7b/how-t...
# 3   https://dev.to/suryanag0999/how-to-deploy-a-vi...
# 4   https://dev.to/apexgov/compatibilidad-entre-ap...
# 5   https://dev.to/arekrgw/nextjs-shallow-search-p...
# 6   https://dev.to/angelamchoi/what-hogwarts-can-t...
# 7   https://dev.to/francescobianco/convcommit-the-...
# 8   https://dev.to/bhabani_sankar/bootstrap-a-comp...
# 9     https://dev.to/lau_blog/the-logic-of-value-4mbb
# 10  https://dev.to/dantesbytes/comprehensive-rust-...
# 11  https://dev.to/rijultp/how-to-build-habit-form...
# 12  https://dev.to/samvanhoutte/processing-time-se...
# 13  https://dev.to/hijazi313/nextjs-15-scroll-beha...
# 14  https://dev.to/leapcell/rust-concurrency-a-beg...
# 15  https://dev.to/proga100/slash-your-wordpress-s...
# 16  https://dev.to/michaellarocca/mastering-excel-...
# 17  https://dev.to/omriluz1/promise-combinators-ra...
# 18  https://dev.to/bansikah/aws-config-automate-yo...
# 19  https://dev.to/proga100/automating-wordpress-s...
# 20  https://dev.to/l_walid/concurrency-gotchas-in-...
# 21      https://dev.to/yarynakobryn/vistra-review-aa8
# 22  https://dev.to/anacvera/login-seguro-com-robot...
# 23  https://dev.to/adityav369/an-overview-of-rules...
# 24  https://dev.to/kampa/introducing-kampaio-local...
#
#                                                 Title         Time Uploaded  \
# 0   Ng-News 25/12: Nx Angular Week, Deprecation PR...  2025-03-24T21:13:50Z
# 1                               Full Stack Dev Needed  2025-03-24T21:14:52Z
# 2   How to automate outbound voice calls with AI u...  2025-03-24T21:10:19Z
# 3      How to Deploy a Vite React App to GitHub Pages  2025-03-24T20:59:34Z
# 4    Compatibilidad entre Apex y Base de datos Oracle  2025-03-24T20:59:09Z
# 5               Next.js shallow search params routing  2025-03-24T20:56:05Z
# 6           What Hogwarts Can Teach Us About Security  2025-03-24T20:46:12Z
# 7   How to Make Conventional Commits a Lasting Habit?  2025-03-24T20:42:08Z
# 8                         Bootstrap: A Complete Guide  2025-03-24T20:41:49Z
# 9                                  The logic of Value  2025-03-24T20:38:27Z
# 10              Comprehensive Rust Programming Course  2025-03-24T20:38:03Z
# 11  How to Build Habit-Forming Products Using Nir ...  2025-03-24T20:37:37Z
# 12  Processing Time Series data in Azure: the options  2025-03-24T20:17:58Z
# 13  Next.js 15 Scroll Behavior: A Comprehensive Guide  2025-03-24T20:16:04Z
# 14         Rust Concurrency: A Beginner's Exploration  2025-03-24T20:11:45Z
# 15  🚀 Slash Your WordPress Setup Time to Seconds w...  2025-03-24T20:08:27Z
# 16  Mastering Excel: VLOOKUP and Custom VBA Functi...  2025-03-24T20:04:41Z
# 17         Promise Combinators: race, allSettled, any  2025-03-24T19:59:33Z
# 18  AWS Config: Automate Your Cloud Compliance and...  2025-03-24T19:56:40Z
# 19  Automating WordPress Site Creation in Laravel ...  2025-03-24T19:54:51Z
# 20                          Concurrency gotchas in go  2025-03-24T19:44:22Z
# 21                                      Vistra Review  2025-03-24T19:54:14Z
# 22  🔐 Login Seguro com Robot Framework: Protegendo...  2025-03-24T19:35:41Z
# 23  An overview of rules based ingestion in DataBr...  2025-03-24T19:29:17Z
# 24  Introducing Kampa.io - Local Dev Environments ...  2025-03-24T19:24:12Z
#
#                           Author                                        Tags  \
# 0                        ng-news      #programming#webdev#javascript#angular
# 1                            Don                        #career#node#aws#git
# 2            Dimitrije Gujanicic
# 3                      surya nag                   #react#vite#github#webdev
# 4   Javier Arley Sanchez Ledesma               #orclapex#oracle#database#web
# 5               Arkadiusz Pawlak            #react#nextjs#webdev#programming
# 6                    Angela Choi                                   #security
# 7               Francesco Bianco  #conventionalcommit#git#commit#programming
# 8                 Bhabani Sankar     #webdev#programming#bootstrap#beginners
# 9                            Lau               #cybersecurity#security#owasp
# 10                         Dante
# 11                  Rijul Rajesh                               #ui#ux#webdev
# 12                 Sam Vanhoutte            #azure#timeseries#database#kusto
# 13                Muhammad Hamza             #nextjs#react#webdev#javascript
# 14                      Leapcell            #webdev#programming#backend#rust
# 15            Rustamjon Akhmedov           #python#wordpress#automation#herd
# 16            Michael J. Larocca       #vba#microsoft#programming#codenewbie
# 17                      omri luz     #javascript#programming#webdev#advanced
# 18          Tandap Noel Bansikah             #aws#security#compliance#devops
# 19            Rustamjon Akhmedov        #wordpress#laravel#python#automation
# 20                Walid LAGGOUNE                           #go#backend#go101
# 21                 Yaryna Kobryn                                 #eorreviews
# 22                      Ana Vera
# 23         Adityavardhan Agrawal                   #rag#ai#python#opensource
# 24                  Diego S Mota             #news#webdev#programming#docker
#
#    Reading Time                                    Article Content  \
# 0    2 min read  Nx showcased their Angular support during the ...
# 1    1 min read
# 2    1 min read  I'm working on building an AI-powered voice ca...
# 3    2 min read  How to Deploy a Vite React App to GitHub Pages...
# 4    1 min read  Este cuadro muestra las versiones de Oracle AP...
# 5    2 min read  If you ever used Pages Router from Next.js you...
# 6    2 min read  How does Hogwarts keep its magical secrets saf...
# 7    2 min read  Conventional commits sound great in theory: st...
# 8    7 min read  What is Bootstrap? How to Use Bootstrap? Addin...
# 9    3 min read  Not all threats matters equally, and not all v...
# 10   7 min read
# 11   3 min read  Ever wondered why you can’t stop scrolling thr...
# 12   4 min read  Time series data are data points that are coll...
# 13   4 min read  Next.js 15 introduced significant improvements...
# 14   8 min read   Many people cannot distinguish between the co...
# 15   2 min read  If you're tired of wasting precious developmen...
# 16  11 min read   When it comes to writing programs, they don’t...
# 17   5 min read  Promises in JavaScript represent a powerful as...
# 18   6 min read  Did you know that cloud misconfigurations caus...
# 19   2 min read  A Python tool that streamlines WordPress devel...
# 20   5 min read  Hi, my name is Walid, a backend developer who’...
# 21   9 min read  Founded in 1986, Vistra International began as...
# 22   1 min read  👋 Se você usa o Robot Framework nos seus teste...
# 23   6 min read  Rules! Rules! Rules! LLMs are exceptionally go...
# 24   2 min read  It's fast, consistent, and collaborative - jus...
#
#     Word Count Sentiment  Compound Score
# 0          466  Positive          0.9915
# 1            0   Neutral          0.0000
# 2           89  Positive          0.9782
# 3          306  Positive          0.9804
# 4           17   Neutral          0.0000
# 5          144  Positive          0.9877
# 6          375  Positive          0.9944
# 7          168  Positive          0.9846
# 8          892  Positive          0.9873
# 9          535  Negative         -0.8216
# 10           0   Neutral          0.0000
# 11         358  Positive          0.9980
# 12         603  Positive          0.9874
# 13         378  Positive          0.9912
# 14         776  Positive          0.9923
# 15         156  Positive          0.7805
# 16        1507  Positive          0.9999
# 17         471  Positive          0.9970
# 18         993  Positive          0.9991
# 19         104  Positive          0.8707
# 20         657  Positive          0.9982
# 21        1252  Positive          0.9997
# 22         198  Negative         -0.6662
# 23         439  Positive          0.9921
# 24         123  Positive          0.9672

# %%
import pandas as pd

df.columns = [x.lower() for x in df.columns]
df.columns = [x.replace(' ','_') for x in df.columns]
df['reading_time'] = df['reading_time'].str.replace(' min read','')
df['article_content'] = df['article_content'].str.replace('\n','')


df = df.astype({
    'link': 'string',
    'title': 'string',
    'time_uploaded': 'string',  # Can be converted to datetime later
    'author': 'string',
    'tags': 'string',
    'reading_time': 'int64',
    'article_content': 'string',
    'word_count': 'int64',
    'sentiment': 'string',
    'compound_score': 'float64'
})


df['time_uploaded'] = pd.to_datetime(df['time_uploaded'])

# %%
import psycopg2
import pandas as pd

# Database connection parameters
db_params = {
    "dbname": "postgres",
    "user": "testtech",
    "password": "Your_password",
    "host": "testtech.postgres.database.azure.com",
    "port": "5432"
}


try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_params)
    cursor = conn.cursor()
    
    # SQL Insert Query
    insert_query = """
    INSERT INTO michael (link, title, time_uploaded, author, tags, reading_time, article_content, word_count, sentiment, compound_score)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (link) DO NOTHING;  -- Avoids duplicate primary key errors
    """
    
    # Insert DataFrame records one by one
    for _, row in df.iterrows():
        cursor.execute(insert_query, (
            row['link'], row['title'], row['time_uploaded'], row['author'], row['tags'],
            row['reading_time'], row['article_content'], row['word_count'], row['sentiment'], row['compound_score']
        ))

    # Commit and close
    conn.commit()
    print("Data inserted successfully!")

except Exception as e:
    print("Error:", e)

finally:
    if conn:
        cursor.close()
        conn.close()




#"password": os.getenv("DB_PASSWORD")
# Out:
# Data inserted successfully!

# %%
#pip install psycopg2
# Out:
# Collecting psycopg2
#   Using cached psycopg2-2.9.10-cp312-cp312-linux_x86_64.whl
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10
# Note: you may need to restart the kernel to use updated packages.
